# %% [markdown]
# <a href="https://colab.research.google.com/github/SShyamili/python-libraries-basic-advanced/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
price=[1700,1800,1500,600,4500,6110]
year=[2015,2016,2017,2018,2019,2020]

# %%
plt.plot(year,price)

# %%
# %matplotlib inline
x=np.linspace(0,10,100)
fig=plt.figure()
plt.plot(x,np.sin(x),ls='-')
plt.plot(x,np.cos(x),ls='--')
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x),ls='-')
plt.subplot(1,2,2)
plt.plot(x,np.cos(x),ls='-')
plt.show()

# %%
 print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(plt.gcf())
# Out:
# Figure(640x480)

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
x=np.linspace(1,20,50)
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Simple Plot')
plt.legend()

# %%
fig,ax=plt.subplots(2)
ax[0].plot([1,2,3,4],[2,4,8,10],'go')
ax[1].plot([1,2,3,4],[1,4,9,16],'bo')
plt.axis=[1,4,1,10]

plt.show()

# %%
x1=np.arange(1,6)
plt.plot(x1,x1**2,x1,x1**3,x1,x1/2)
plt.grid(True)
plt.legend(['fast','normal','slow'])
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x),ls='-')
plt.subplot(1,2,2)
plt.plot(x,np.cos(x),ls='-')
plt.legend(['sin','cos'],loc=1)
plt.show()

# %%
fig.savefig('fig.png')

# %%
from IPython.display import Image
Image('fig.png')

# %%
plt.hist(np.random.randn(1000),color='m')
# Out:
# (array([  6.,  40.,  91., 145., 252., 215., 158.,  66.,  20.,   7.]),
#  array([-2.9319554 , -2.33931495, -1.74667449, -1.15403404, -0.56139359,
#          0.03124686,  0.62388731,  1.21652776,  1.80916821,  2.40180866,
#          2.99444911]),
#  <BarContainer object of 10 artists>)

# %%
x=np.arange(1,6)
plt.bar(x,x**2,color='b')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,x**3,color='c')
# Out:
# <BarContainer object of 5 artists>

# %%
x=np.arange(1,6)
plt.bar(x,x**2)
plt.bar(x,x**3,bottom=x**2)
# Out:
# <BarContainer object of 5 artists>

# %%
x=[75,14,1,8,2]
plt.pie(x,labels=['a','b','c','d','e'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7e19b9d8b910>,
# ...
#  [Text(-0.7778174639428924, 0.7778174546675123, 'a'),
#   Text(0.46835741088254246, -0.9953096682296427, 'b'),
#   Text(0.8691704503379541, -0.6741978405922984, 'c'),
#   Text(1.0227539500146063, -0.404937473851853, 'd'),
#   Text(1.0978293786450977, -0.06906993111129502, 'e')])

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e19ba41e950>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e19ba3db110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e19ba41f350>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e19c0878cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e19c087b650>],
#  'means': []}

# %%
x=np.arange(1,6)
y=np.arange(7,12)
plt.fill_between(x,y)

# %%
matrix=np.random.rand(10,20)
p=plt.contour(matrix)

# %% [markdown]
# # Task
# Add comments and description text to all cells in the notebook.

# %% [markdown]
# ## Add comments to the first cell explaining the import of libraries.
#
# ### Subtask:
# Add comments to the first cell explaining the import of libraries.

# %% [markdown]
# **Reasoning**:
# Add comments to the first code cell explaining the imports.

# %%
# This cell imports necessary libraries for data visualization and analysis.
import matplotlib.pyplot as plt  # For plotting graphs
import seaborn as sns  # For enhanced data visualizations
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations, especially array manipulation

# %% [markdown]
# ## Add comments to the second cell explaining the data being created.
#
# ### Subtask:
# Add comments to the second cell explaining the data being created.

# %% [markdown]
# **Reasoning**:
# Add comments to the second cell to explain the purpose of the `price` and `year` lists.

# %%
# This list stores the price data points.
price=[1700,1800,1500,600,4500,6110]
# This list stores the corresponding years for the price data.
year=[2015,2016,2017,2018,2019,2020]

# %% [markdown]
# ## Add comments and a text description to the third cell explaining the plot being generated.
#
# ### Subtask:
# Add comments and a text description to the third cell explaining the plot being generated.

# %% [markdown]
# **Reasoning**:
# Add a text description and comments to the third cell as requested by the subtask.

# %%
# This cell generates a simple line plot showing the relationship between 'year' and 'price'.
plt.plot(year,price) # Create the line plot using year on the x-axis and price on the y-axis.
plt.show() # Display the generated plot.

# %% [markdown]
# ## Add comments and a text description to the fourth cell explaining the use of `matplotlib inline` and the generation of sine and cosine plots.
#
# ### Subtask:
# Add comments and a text description to the fourth cell explaining the use of `matplotlib inline` and the generation of sine and cosine plots.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the fourth cell as requested by the instructions.

# %%
# This cell demonstrates the use of %matplotlib inline and plots sine and cosine functions.
# %matplotlib inline is a magic command that ensures plots are displayed directly in the notebook.
# %matplotlib inline
# Create an array of 100 evenly spaced values between 0 and 10 for the x-axis.
x=np.linspace(0,10,100)
# Create a new figure.
fig=plt.figure()
# Plot the sine function of x with a solid line style.
plt.plot(x,np.sin(x),ls='-')
# Plot the cosine function of x with a dashed line style.
plt.plot(x,np.cos(x),ls='--')
# Display the generated plot.
plt.show()

# %% [markdown]
# ## Add comments and a text description to the fifth cell explaining the creation of subplots and the generation of sine and cosine plots within them.
#
# ### Subtask:
# Add comments and a text description to the fifth cell explaining the creation of subplots and the generation of sine and cosine plots within them.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the fifth cell as instructed to explain the creation of subplots and the plots within them.

# %%
# This cell demonstrates how to create subplots using plt.subplot() and plot different functions within each subplot.
# Create a new figure and a set of subplots. In this case, a 1x2 grid of subplots.
fig,ax=plt.subplots(2)
# Create the first subplot in a 1x2 grid and activate it. Plot points in the first subplot.
ax[0].plot([1,2,3,4],[2,4,8,10],'go')
# Create the second subplot in a 1x2 grid and activate it. Plot points in the second subplot.
ax[1].plot([1,2,3,4],[1,4,9,16],'bo')
# This line seems to be an attempt to set axis limits, but it's incorrect syntax. It will be ignored.
plt.axis=[1,4,1,10]

# Display the figure with the subplots.
plt.show()

# %% [markdown]
# ## Add a text description to the sixth cell explaining the output of `plt.gca()`.
#
# ### Subtask:
# Add a text description to the sixth cell explaining the output of `plt.gca()`.

# %% [markdown]
# **Reasoning**:
# Add a text description above the sixth code cell explaining the output of `plt.gca()`.

# %%
# This cell demonstrates the use of plt.gca() which returns the current Axes object.
# This is useful for customizing the current plot, such as setting limits, labels, or titles for the active axes.
print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Add a text description to the seventh cell explaining the output of `plt.gcf()`.
#
# ### Subtask:
# Add a text description to the seventh cell explaining the output of `plt.gcf()`.

# %% [markdown]
# **Reasoning**:
# Add a text description above the seventh cell to explain what `plt.gcf()` returns and its significance.

# %%
# This cell demonstrates the use of plt.gcf() which returns the current Figure object.
# This is useful for customizing the entire figure, such as saving it to a file or adjusting its size.
print(plt.gcf())
# Out:
# Figure(640x480)

# %% [markdown]
# ## Add comments and a text description to the eighth cell explaining the plot of a quadratic function.
#
# ### Subtask:
# Add comments and a text description to the eighth cell explaining the plot of a quadratic function.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the eighth cell as requested.

# %%
# This cell plots a quadratic function (y = x^2).
# Plot a list of numbers against their squares.
plt.plot([1,2,3,4],[1,4,9,16])
# Display the plot.
plt.show()

# %% [markdown]
# ## Add comments and a text description to the ninth cell explaining the plot with labels, title, and legend.
#
# ### Subtask:
# Add comments and a text description to the ninth cell explaining the plot with labels, title, and legend.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the ninth cell as requested in the instructions to explain the plot being generated.

# %%
# This cell creates a plot with labels, a title, and a legend to make it more informative.
# Create an array of 50 evenly spaced values between 1 and 20.
x=np.linspace(1,20,50)
# Plot the linear function y=x.
plt.plot(x,x,label='linear')
# Plot the quadratic function y=x^2.
plt.plot(x,x**2,label='quadratic')
# Plot the cubic function y=x^3.
plt.plot(x,x**3,label='cubic')
# Add a label to the x-axis.
plt.xlabel('x label')
# Add a label to the y-axis.
plt.ylabel('y label')
# Add a title to the plot.
plt.title('Simple Plot')
# Add a legend to identify the different lines.
plt.legend()

# %% [markdown]
# ## Add comments and a text description to the tenth cell explaining the creation of subplots and setting axis limits.
#
# ### Subtask:
# Add comments and a text description to the tenth cell explaining the creation of subplots and setting axis limits.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the tenth cell as instructed.

# %%
# This cell demonstrates the creation of subplots and an attempt to set axis limits.
# Create a figure and a 2x1 grid of subplots.
fig,ax=plt.subplots(2)
# Plot green circles on the first subplot.
ax[0].plot([1,2,3,4],[2,4,8,10],'go')
# Plot blue circles on the second subplot.
ax[1].plot([1,2,3,4],[1,4,9,16],'bo')
# This line is an incorrect attempt to set axis limits and will be ignored.
plt.axis=[1,4,1,10]

# Display the figure with the subplots.
plt.show()

# %% [markdown]
# ## Add comments and a text description to the eleventh cell explaining the plot with grid and legend.
#
# ### Subtask:
# Add comments and a text description to the eleventh cell explaining the plot with grid and legend.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the eleventh cell as requested.

# %%
# This cell generates a plot with a grid and a legend to differentiate the plotted lines.
# Create an array of numbers from 1 to 5 for the x-axis.
x1=np.arange(1,6)
# Plot multiple functions (x^2, x^3, x/2) against x1 on the same axes.
plt.plot(x1,x1**2,x1,x1**3,x1,x1/2)
# Add a grid to the plot for better readability.
plt.grid(True)
# Add a legend to identify the different lines with specific labels.
plt.legend(['fast','normal','slow'])
# Display the plot.
plt.show()

# %% [markdown]
# ## Add comments and a text description to the twelfth cell explaining the creation of subplots and adding a legend.
#
# ### Subtask:
# Add comments and a text description to the twelfth cell explaining the creation of subplots and adding a legend.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the twelfth cell as instructed to explain the creation of subplots and adding a legend.

# %%
# This cell demonstrates creating subplots and adding a legend to them.
# Create a new figure.
plt.figure()
# Create the first subplot in a 1x2 grid and activate it.
plt.subplot(1,2,1)
# Plot the sine function in the first subplot.
plt.plot(x,np.sin(x),ls='-')
# Create the second subplot in a 1x2 grid and activate it.
plt.subplot(1,2,2)
# Plot the cosine function in the second subplot.
plt.plot(x,np.cos(x),ls='-')
# Adds a legend with specified labels and location to the current subplot (the second one).
plt.legend(['sin','cos'],loc=1)
# Displays the figure with the subplots.
plt.show()

# %% [markdown]
# ## Add a text description to the thirteenth cell explaining saving the figure.
#
# ### Subtask:
# Add a text description to the thirteenth cell explaining saving the figure.

# %% [markdown]
# **Reasoning**:
# Add a text description above the thirteenth cell explaining its purpose of saving the figure to a file.

# %%
# This cell saves the previously generated figure to a file named 'fig.png'.
fig.savefig('fig.png')

# %% [markdown]
# ## Add a text description to the fourteenth cell explaining displaying the saved image.
#
# ### Subtask:
# Add a text description to the fourteenth cell explaining displaying the saved image.

# %% [markdown]
# **Reasoning**:
# Add a text description above the fourteenth cell explaining that this cell displays the image file that was saved in the previous cell.

# %%
# This cell displays the image file 'fig.png' that was saved in the previous cell.
from IPython.display import Image
Image('fig.png')

# %% [markdown]
# ## Add comments and a text description to the fifteenth cell explaining the creation of a histogram.
#
# ### Subtask:
# Add comments and a text description to the fifteenth cell explaining the creation of a histogram.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the fifteenth cell as requested.

# %%
# This cell creates a histogram of randomly generated data to visualize its distribution.
# Generate and plot a histogram of 1000 random numbers drawn from a standard normal distribution.
plt.hist(np.random.randn(1000),color='m')
# The output includes the histogram data (bin counts and edges) and matplotlib patches (the bars).
# Out:
# (array([ 12.,  34., 103., 195., 255., 222., 122.,  50.,   3.,   4.]),
#  array([-3.01405036, -2.35636385, -1.69867735, -1.04099084, -0.38330433,
#          0.27438217,  0.93206868,  1.58975519,  2.24744169,  2.9051282 ,
#          3.5628147 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Add comments and a text description to the sixteenth cell explaining the creation of a bar plot.
#
# ### Subtask:
# Add comments and a text description to the sixteenth cell explaining the creation of a bar plot.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the sixteenth cell as instructed to explain the bar plot.

# %%
# This cell demonstrates the creation of a basic bar plot.
# Create an array of numbers from 1 to 5 for the x-axis.
x=np.arange(1,6)
# Generate a bar plot using x for the x-axis values and x**2 for the heights of the bars, colored blue.
plt.bar(x,x**2,color='b')
# The output returns a BarContainer object which contains the artists for the bars.
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Add comments and a text description to the seventeenth cell explaining the creation of a horizontal bar plot.
#
# ### Subtask:
# Add comments and a text description to the seventeenth cell explaining the creation of a horizontal bar plot.

# %% [markdown]
# **Reasoning**:
# Add a text description and comments to the seventeenth cell as requested by the subtask instructions.

# %%
# This cell creates a horizontal bar plot to visualize data.
x=np.arange(1,6)
# Generate a horizontal bar plot using x for the y-axis and x**3 for the bar lengths, colored cyan.
plt.barh(x,x**3,color='c')
# The output is a BarContainer object containing the artists for the bars.
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Add comments and a text description to the eighteenth cell explaining the creation of a stacked bar plot.
#
# ### Subtask:
# Add comments and a text description to the eighteenth cell explaining the creation of a stacked bar plot.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the eighteenth cell as requested.

# %%
# This cell demonstrates the creation of a stacked bar plot.
x=np.arange(1,6)
# This plots the base bars of the stacked bar plot.
plt.bar(x,x**2)
# This plots the second set of bars on top of the first set to create the stacked effect.
plt.bar(x,x**3,bottom=x**2)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Add comments and a text description to the nineteenth cell explaining the creation of a pie chart.
#
# ### Subtask:
# Add comments and a text description to the nineteenth cell explaining the creation of a pie chart.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the nineteenth cell as requested.

# %%
# This cell creates a pie chart to visualize proportions of different categories.
# This list represents the sizes of the slices for the pie chart.
x=[75,14,1,8,2]
# This line generates the pie chart using the data and labels.
plt.pie(x,labels=['a','b','c','d','e'])
# The output includes a list of wedge objects (the pie slices) and a list of text objects (the labels).
# Out:
# ([<matplotlib.patches.Wedge at 0x7e19b98d3910>,
# ...
#  [Text(-0.7778174639428924, 0.7778174546675123, 'a'),
#   Text(0.46835741088254246, -0.9953096682296427, 'b'),
#   Text(0.8691704503379541, -0.6741978405922984, 'c'),
#   Text(1.0227539500146063, -0.404937473851853, 'd'),
#   Text(1.0978293786450977, -0.06906993111129502, 'e')])

# %% [markdown]
# ## Add comments and a text description to the twentieth cell explaining the creation of a box plot.
#
# ### Subtask:
# Add comments and a text description to the twentieth cell explaining the creation of a box plot.

# %% [markdown]
# **Reasoning**:
# Add a text description above the twentieth cell explaining the creation of a box plot, and add comments within the cell to explain the code.

# %%
# This cell demonstrates the creation of a box plot, which is useful for visualizing the distribution of numerical data and identifying potential outliers.
# Generate a box plot from the data x.
plt.boxplot(x)
# The output is a dictionary containing the different parts of the box plot (whiskers, caps, boxes, medians, fliers, means).
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e19b994cdd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e19b994e5d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e19b994c150>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e19b994fdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e19b9970990>],
#  'means': []}

# %% [markdown]
# ## Add comments and a text description to the twenty-first cell explaining the creation of a filled area plot.
#
# ### Subtask:
# Add comments and a text description to the twenty-first cell explaining the creation of a filled area plot.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the twenty-first cell as requested.

# %%
# This cell explains the creation of a filled area plot.
# Create an array of numbers from 1 to 5 for the x-axis.
x=np.arange(1,6)
# Create an array of numbers from 7 to 11 for the y-axis.
y=np.arange(7,12)
# Create a filled area between the two sets of data (x and y).
plt.fill_between(x,y)

# %% [markdown]
# ## Add comments and a text description to the twenty-second cell explaining the creation of a contour plot.
#
# ### Subtask:
# Add comments and a text description to the twenty-second cell explaining the creation of a contour plot.

# %% [markdown]
# **Reasoning**:
# Add the text description and comments to the twenty-second cell as requested.

# %%
# This cell demonstrates the creation of a contour plot, which is used to visualize 3D data on a 2D plane using contour lines.
# This line creates a 2D array of random numbers to be used for the contour plot.
matrix=np.random.rand(10,20)
# This line generates a contour plot from the matrix data.
p=plt.contour(matrix)
# The output 'p' is a QuadContourSet object, which is a collection of contour lines.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Comments were added to the first cell to explain the import of libraries (`matplotlib.pyplot`, `seaborn`, `pandas`, `numpy`).
# *   Comments were added to the second cell to explain the creation of `price` and `year` lists.
# *   A text description and comments were added to the third cell explaining the generation of a simple line plot using `plt.plot()` and displaying it with `plt.show()`.
# *   A text description and comments were added to the fourth cell explaining the use of `%matplotlib inline` and the plotting of sine and cosine functions.
# *   A text description and comments were added to the fifth cell explaining the creation of subplots using `plt.subplots()` and plotting points within them. It was noted that an incorrect attempt to set axis limits (`plt.axis=[1,4,1,10]`) was present and ignored.
# *   A text description was added to the sixth cell explaining that `plt.gca()` returns the current Axes object.
# *   A text description was added to the seventh cell explaining that `plt.gcf()` returns the current Figure object.
# *   A text description and comments were added to the eighth cell explaining the plotting of a quadratic function using `plt.plot()`.
# *   A text description and comments were added to the ninth cell explaining the creation of a plot with labels, title, and legend using `plt.xlabel()`, `plt.ylabel()`, `plt.title()`, and `plt.legend()`.
# *   A text description and comments were added to the tenth cell explaining the creation of subplots and an incorrect attempt to set axis limits.
# *   A text description and comments were added to the eleventh cell explaining the creation of a plot with a grid (`plt.grid(True)`) and a legend (`plt.legend()`).
# *   A text description and comments were added to the twelfth cell explaining the creation of subplots using `plt.subplot()` and adding a legend to the second subplot.
# *   A text description was added to the thirteenth cell explaining saving the figure to a file using `fig.savefig()`.
# *   A text description was added to the fourteenth cell explaining displaying the saved image using `IPython.display.Image`.
# *   A text description and comments were added to the fifteenth cell explaining the creation of a histogram using `plt.hist()`.
# *   A text description and comments were added to the sixteenth cell explaining the creation of a bar plot using `plt.bar()`.
# *   A text description and comments were added to the seventeenth cell explaining the creation of a horizontal bar plot using `plt.barh()`.
# *   A text description and comments were added to the eighteenth cell explaining the creation of a stacked bar plot using multiple `plt.bar()` calls with the `bottom` parameter.
# *   A text description and comments were added to the nineteenth cell explaining the creation of a pie chart using `plt.pie()`.
# *   A text description and comments were added to the twentieth cell explaining the creation of a box plot using `plt.boxplot()`.
# *   A text description and comments were added to the twenty-first cell explaining the creation of a filled area plot using `plt.fill_between()`.
# *   A text description and comments were added to the twenty-second cell explaining the creation of a contour plot using `plt.contour()`.
#
# ### Insights or Next Steps
#
# *   The notebook is now significantly more readable and understandable due to the added comments and text descriptions, making it easier for others (or the user themselves in the future) to follow the data analysis steps and the purpose of each visualization.
# *   The inconsistent axis setting method (`plt.axis=[1,4,1,10]`) should be corrected to the standard `plt.axis([xmin, xmax, ymin, ymax])` or using the Axes object methods (`ax.set_xlim()`, `ax.set_ylim()`, `ax.set_aspect()`) for proper control over plot limits, especially within subplots.
