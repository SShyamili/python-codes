# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\S SHYAMILI\OneDrive\Desktop\data science\NOTES\titanic dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# '''relational plots'''

# %%
sns.scatterplot(data=data,x='Survived',y="Age")
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.relplot(data=data,x='Survived',y="Age",hue='Sex',style='SibSp',size='Pclass')

# %%
sns.lineplot(data=data,x='Survived',y='Age',hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.relplot(data=data,x='Survived',y='Age',kind='line')

# %%
sns.relplot(data=data,x='Survived',y='Age',col='Sex',hue='Survived',row='Survived')

# %% [markdown]
# '''Distribution plots'''

# %%
sns.histplot(data=data,x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.displot(data=data,x='Age',kind='hist',hue='Survived')

# %%
sns.kdeplot(data=data,x='Age',hue='Sex',fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(data=data,x='Age',kind='kde',fill=True)

# %%
sns.histplot(data=data,x='Age',y='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
sns.kdeplot(data=data,x='Age',y='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
#del data['PassengerId']
#del data['Pclass']
#del data['Name']
#del data['Cabin']
#del data['Embarked']
#del data['Parch']
del data['Ticket']
del data['Fare']

# %%
data
# Out:
#      Survived     Sex   Age  SibSp
# 0           0    male  22.0      1
# 1           1  female  38.0      1
# 2           1  female  26.0      0
# 3           1  female  35.0      1
# 4           0    male  35.0      0
# ..        ...     ...   ...    ...
# 886         0    male  27.0      0
# 887         1  female  19.0      0
# 888         0  female   NaN      1
# 889         1    male  26.0      0
# 890         0    male  32.0      0
#
# [891 rows x 4 columns]

# %%
num_cols = ["Survived", "Age"]

# Compute correlation matrix
corr_matrix = data[num_cols].corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Dataset")
plt.show()

# %% [markdown]
# categorical

# %%
sns.stripplot(data=data,x='Survived',y='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
sns.catplot(data=data,x='Survived',y='Sex',kind='swarm',hue='Sex')

# %%
sns.boxplot(data=data,x='Sex',y='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(data=data,y='Survived',hue='Sex')
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.violinplot(data=data,x='Sex',y='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(data=data,x='Sex',y='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.countplot(data=data,x='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.pointplot(data=data,x='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# Regression plot

# %%
sns.regplot(data=data,x='Survived',y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.residplot(data=data,x='Survived',y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
g=sns.FacetGrid(data=data,row='Sex',col='Survived')
g.map(sns.violinplot,'Sex','Survived')

# %%
g=sns.FacetGrid(data=data,row='Sex',col='Survived')
g.map(sns.countplot,'Sex')

# %%
sns.pairplot(data,hue='Sex')

# %%
g=sns.PairGrid(data=data,hue='Sex')
g.map(sns.scatterplot)

# %%
sns.jointplot(data=data,x='Survived',y='SibSp')

# %%
g=sns.JointGrid(data=data[['Survived','Sex']])
g.plot(sns.barplot,sns.violinplot)
